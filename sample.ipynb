# %%
def genrate():
    print("Hello World!")
    return "Calling the function genrate()"

# %%
response = genrate()
# Out:
# Hello World!

# %%
full_response = "Here is the response: " + str(response)
print(full_response)
# Out:
# Here is the response: Calling the function genrate()
